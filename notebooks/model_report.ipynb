# %% [markdown]
# # DeepCTR Model Comparison
#
# Use this notebook to visualize metrics stored under `reports/` and compare baselines against DeepFM. Suggested workflow:
#
# 1. Load CSV logs (e.g., `reports/baseline_metrics.csv`, `reports/deepfm_metrics.csv`).
# 2. Plot training/validation losses and validation AUC curves.
# 3. Summarize the best-performing configuration and note deployment considerations.
